# %%
# !spark-submit --version
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 3.5.0
#       /_/
#
# Using Scala version 2.12.18, OpenJDK 64-Bit Server VM, 17.0.8.1
# Branch HEAD
# Compiled by user ubuntu on 2023-09-09T01:53:20Z
# Revision ce5ddad990373636e94071e7cef2f31021add07b
# Url https://github.com/apache/spark
# Type --help for more information.

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler
from pyspark.ml import Estimator, Model
from pyspark.ml.param.shared import HasMaxIter, HasLearningRate
from pyspark.ml.param import Param, Params, TypeConverters

import numpy as np

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("local[*]") \
    .getOrCreate()

# %%
rng = np.random.default_rng(42)

w_tr = np.array([1.5, 0.3, -0.7])
X = rng.standard_normal((10_000, 3))
noise = rng.standard_normal(10_000) * 0.1
y = np.dot(X, w_tr) + noise

# %%
data = np.column_stack((X, y))
columns = ['feature1', 'feature2', 'feature3', 'label']
df = spark.createDataFrame(data.tolist(), columns)

# %%
vector = VectorAssembler(inputCols=['feature1', 'feature2', 'feature3'], outputCol='features')
df = vector.transform(df)

# %% [markdown]
# ### Реализация Linear Regression

# %%
class MyParams(HasLearningRate, HasMaxIter):
    def __init__(self):
        super(MyParams, self).__init__()
        HasLearningRate.__init__(self)
        HasMaxIter.__init__(self)

    def setParams(self, learningRate, maxIter):
        self._set(learningRate=learningRate, maxIter=maxIter)
        return self

# %%
class MyModel(Model, MyParams):
    def __init__(self, weights, bias):
        super(MyModel, self).__init__()
        MyParams.__init__(self)
        self.weights = weights
        self.bias = bias

    def _transform(self, dataset):
        def predict(row):
            features = row.features
            prediction = float(np.dot(self.weights, features) + self.bias)
            return (float(row.label), prediction)

        rdd = dataset.rdd.map(predict)
        return dataset.sparkSession.createDataFrame(rdd, ["label", "prediction"])

# %%
class MyEstimator(Estimator, MyParams):
    def __init__(self):
        super(MyEstimator, self).__init__()
        MyParams.__init__(self)

    def _fit(self, dataset):
        lr = self.getLearningRate()
        maxIter = self.getMaxIter()

        rdd = dataset.rdd.map(lambda row: (np.array(row.features), row.label)).cache()
        num_features = len(rdd.first()[0])
        n = rdd.count()

        weights = np.zeros(num_features)
        bias = 0.0

        for epoch in range(maxIter):
            def compute_gradients(row):
                x, y = row
                y_pred = np.dot(weights, x) + bias
                error = y_pred - y
                return x * error, error

            grad_sum = rdd.map(compute_gradients).reduce(
                lambda a, b: (a[0] + b[0], a[1] + b[1])
            )

            weights -= lr * grad_sum[0] / n
            bias -= lr * grad_sum[1] / n

            if (epoch + 1) % 10 == 0:
                print(f"Epoch {epoch+1}: weights={weights}, bias={bias}")

        model = MyModel(weights, bias)
        model.setParams(learningRate=lr, maxIter=maxIter)
        rdd.unpersist()
        return model

# %%
estimator = MyEstimator().setParams(learningRate=0.1, maxIter=100)
model = estimator.fit(df)

predictions = model.transform(df)
# Out:
# Epoch 10: weights=[ 0.98420786  0.19670666 -0.45041005], bias=0.014084268507447158
# Epoch 20: weights=[ 1.32222551  0.26433804 -0.61085916], bias=0.009500660668445748
# Epoch 30: weights=[ 1.43839828  0.28768199 -0.66799284], bias=0.004617253909960631
# Epoch 40: weights=[ 1.4783545   0.29577151 -0.68833025], bias=0.0017764888924025701
# Epoch 50: weights=[ 1.49210702  0.298586   -0.69556743], bias=0.0003912962853954544
# Epoch 60: weights=[ 1.49684398  0.2995691  -0.69814216], bias=-0.00022872753869157688
# Epoch 70: weights=[ 1.49847681  0.29991384 -0.69905797], bias=-0.0004925522458437267
# Epoch 80: weights=[ 1.49904006  0.30003518 -0.69938365], bias=-0.000601120081486141
# Epoch 90: weights=[ 1.4992345   0.30007805 -0.69949946], bias=-0.000644751251587892
# Epoch 100: weights=[ 1.49930167  0.30009325 -0.69954063], bias=-0.0006619791764842667

# %%
w_tr
# Out:
# array([ 1.5,  0.3, -0.7])

# %%
model.weights
# Out:
# array([ 1.49930167,  0.30009325, -0.69954063])
